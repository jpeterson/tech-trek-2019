# %% [markdown]
# # An introduction to geocoding
#
# Geocoders are tools to which you pass in an address / place of interest and it gives back the coordinates of that place.
#
# The **`arcgis.geocoding`** module provides types and functions for geocoding, batch geocoding and reverse geocoding.

# %%
from arcgis.gis import GIS
from arcgis import geocoding

# %%
gis = GIS(profile='agol_profile')

# %% [markdown]
# ## Geocoding addresses
# All geocoding operations are handled by `geocode()` function. It can geocode
#
#  1. single line address
#  2. multi field address
#  3. points of interest
#  4. administrative place names
#  5. postal codes

# %%
results = geocoding.geocode('Phoenix, AZ')
results
# Out:
# [{'address': 'Phoenix, Arizona',
#   'location': {'x': -112.07579999999996, 'y': 33.44825000000003},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'Phoenix, Arizona',
#    'LongLabel': 'Phoenix, AZ, USA',
#    'ShortLabel': 'Phoenix',
#    'Addr_type': 'Locality',
#    'Type': 'City',
#    'PlaceName': 'Phoenix',
#    'Place_addr': 'Phoenix, Arizona',
#    'Phone': '',
#    'URL': '',
#    'Rank': 2,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Phoenix',
#    'MetroArea': 'Phoenix Metro Area',
#    'Subregion': 'Maricopa County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -112.07579999999996,
#    'Y': 33.44825000000003,
#    'DisplayX': -112.07579999999996,
#    'DisplayY': 33.44825000000003,
#    'Xmin': -112.33279999999996,
#    'Xmax': -111.81879999999995,
#    'Ymin': 33.19125000000003,
#    'Ymax': 33.70525000000003,
#    'ExInfo': ''},
#   'extent': {'xmin': -112.33279999999996,
#    'ymin': 33.19125000000003,
#    'xmax': -111.81879999999995,
#    'ymax': 33.70525000000003}},
#  {'address': 'PHX',
#   'location': {'x': -112.00805999999994, 'y': 33.43417000000005},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'PHX',
#    'LongLabel': 'PHX, Phoenix, AZ, USA',
#    'ShortLabel': 'PHX',
#    'Addr_type': 'POI',
#    'Type': 'Airport',
#    'PlaceName': 'PHX',
#    'Place_addr': 'Phoenix, Arizona',
#    'Phone': '',
#    'URL': '',
#    'Rank': 7,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': '',
#    'StType': '',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Phoenix',
#    'MetroArea': '',
#    'Subregion': 'Maricopa County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -112.00805999999994,
#    'Y': 33.43417000000005,
#    'DisplayX': -112.00805999999994,
#    'DisplayY': 33.43417000000005,
#    'Xmin': -112.03305999999995,
#    'Xmax': -111.98305999999994,
#    'Ymin': 33.40917000000005,
#    'Ymax': 33.45917000000005,
#    'ExInfo': ''},
#   'extent': {'xmin': -112.03305999999995,
#    'ymin': 33.40917000000005,
#    'xmax': -111.98305999999994,
#    'ymax': 33.45917000000005}},
#  {'address': 'PHX',
#   'location': {'x': -112.03115999999994, 'y': 33.437580000000025},
#   'score': 100,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 100,
#    'Match_addr': 'PHX',
#    'LongLabel': 'PHX, 3400 E Sky Harbor Blvd, Phoenix, AZ, 85034, USA',
#    'ShortLabel': 'PHX',
#    'Addr_type': 'POI',
#    'Type': 'Airport',
#    'PlaceName': 'PHX',
#    'Place_addr': '3400 E Sky Harbor Blvd, Phoenix, Arizona, 85034',
#    'Phone': '(602) 273-3300',
#    'URL': 'http://www.phxskyharbor.com',
#    'Rank': 9,
#    'AddBldg': '',
#    'AddNum': '3400',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': 'L',
#    'StPreDir': 'E',
#    'StPreType': '',
#    'StName': 'Sky Harbor',
#    'StType': 'Blvd',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': '3400 E Sky Harbor Blvd',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'Downtown',
#    'District': '',
#    'City': 'Phoenix',
#    'MetroArea': 'Phoenix Metro Area',
#    'Subregion': 'Maricopa County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '85034',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -112.03115999999994,
#    'Y': 33.437580000000025,
#    'DisplayX': -112.03115999999994,
#    'DisplayY': 33.437580000000025,
#    'Xmin': -112.06215999999995,
#    'Xmax': -112.00015999999994,
#    'Ymin': 33.40658000000003,
#    'Ymax': 33.468580000000024,
#    'ExInfo': ''},
#   'extent': {'xmin': -112.06215999999995,
#    'ymin': 33.40658000000003,
#    'xmax': -112.00015999999994,
#    'ymax': 33.468580000000024}},
#  {'address': 'Arizona Dr, Phoenix, Arizona, 85021',
#   'location': {'x': -112.095711, 'y': 33.539562000000004},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'Arizona Dr, Phoenix, Arizona, 85021',
#    'LongLabel': 'Arizona Dr, Phoenix, AZ, 85021, USA',
#    'ShortLabel': 'Arizona Dr',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'Arizona Dr, Phoenix, Arizona, 85021',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'Arizona',
#    'StType': 'Dr',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Arizona Dr',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'Central Phoenix',
#    'District': '',
#    'City': 'Phoenix',
#    'MetroArea': 'Phoenix Metro Area',
#    'Subregion': 'Maricopa County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '85021',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -112.095711,
#    'Y': 33.539562000000004,
#    'DisplayX': -112.095711,
#    'DisplayY': 33.539562000000004,
#    'Xmin': -112.096711,
#    'Xmax': -112.09471099999999,
#    'Ymin': 33.538562000000006,
#    'Ymax': 33.540562,
#    'ExInfo': ''},
#   'extent': {'xmin': -112.096711,
#    'ymin': 33.538562000000006,
#    'xmax': -112.09471099999999,
#    'ymax': 33.540562}},
#  {'address': 'Phoenix Dr, Mohave Valley, Arizona, 86440',
#   'location': {'x': -114.58241813475837, 'y': 34.86948363568754},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'Phoenix Dr, Mohave Valley, Arizona, 86440',
#    'LongLabel': 'Phoenix Dr, Mohave Valley, AZ, 86440, USA',
#    'ShortLabel': 'Phoenix Dr',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'Phoenix Dr, Mohave Valley, Arizona, 86440',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Dr',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Phoenix Dr',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Mohave Valley',
#    'MetroArea': '',
#    'Subregion': 'Mohave County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '86440',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -114.58241813475837,
#    'Y': 34.86948363568754,
#    'DisplayX': -114.58241813475837,
#    'DisplayY': 34.86948363568754,
#    'Xmin': -114.58341813475838,
#    'Xmax': -114.58141813475837,
#    'Ymin': 34.86848363568754,
#    'Ymax': 34.870483635687535,
#    'ExInfo': ''},
#   'extent': {'xmin': -114.58341813475838,
#    'ymin': 34.86848363568754,
#    'xmax': -114.58141813475837,
#    'ymax': 34.870483635687535}},
#  {'address': 'Phoenix Rd, Littlefield, Arizona, 86432',
#   'location': {'x': -113.93823572174244, 'y': 36.908062547972236},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'Phoenix Rd, Littlefield, Arizona, 86432',
#    'LongLabel': 'Phoenix Rd, Littlefield, AZ, 86432, USA',
#    'ShortLabel': 'Phoenix Rd',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'Phoenix Rd, Littlefield, Arizona, 86432',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Rd',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Phoenix Rd',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Littlefield',
#    'MetroArea': '',
#    'Subregion': 'Mohave County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '86432',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -113.93823572174244,
#    'Y': 36.908062547972236,
#    'DisplayX': -113.93823572174244,
#    'DisplayY': 36.908062547972236,
#    'Xmin': -113.93923572174245,
#    'Xmax': -113.93723572174244,
#    'Ymin': 36.90706254797224,
#    'Ymax': 36.90906254797223,
#    'ExInfo': ''},
#   'extent': {'xmin': -113.93923572174245,
#    'ymin': 36.90706254797224,
#    'xmax': -113.93723572174244,
#    'ymax': 36.90906254797223}},
#  {'address': 'Phoenix Ave, Kingman, Arizona, 86401',
#   'location': {'x': -114.05320195606464, 'y': 35.177528964486235},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'Phoenix Ave, Kingman, Arizona, 86401',
#    'LongLabel': 'Phoenix Ave, Kingman, AZ, 86401, USA',
#    'ShortLabel': 'Phoenix Ave',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'Phoenix Ave, Kingman, Arizona, 86401',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Ave',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Phoenix Ave',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Kingman',
#    'MetroArea': '',
#    'Subregion': 'Mohave County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '86401',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -114.05320195606464,
#    'Y': 35.177528964486235,
#    'DisplayX': -114.05320195606464,
#    'DisplayY': 35.177528964486235,
#    'Xmin': -114.05420195606465,
#    'Xmax': -114.05220195606464,
#    'Ymin': 35.17652896448624,
#    'Ymax': 35.17852896448623,
#    'ExInfo': ''},
#   'extent': {'xmin': -114.05420195606465,
#    'ymin': 35.17652896448624,
#    'xmax': -114.05220195606464,
#    'ymax': 35.17852896448623}},
#  {'address': 'Phoenix Dr, Lake Havasu City, Arizona, 86404',
#   'location': {'x': -114.29613225, 'y': 34.517448},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'Phoenix Dr, Lake Havasu City, Arizona, 86404',
#    'LongLabel': 'Phoenix Dr, Lake Havasu City, AZ, 86404, USA',
#    'ShortLabel': 'Phoenix Dr',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'Phoenix Dr, Lake Havasu City, Arizona, 86404',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Dr',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Phoenix Dr',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Lake Havasu City',
#    'MetroArea': '',
#    'Subregion': 'Mohave County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '86404',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -114.29613225,
#    'Y': 34.517448,
#    'DisplayX': -114.29613225,
#    'DisplayY': 34.517448,
#    'Xmin': -114.29713225,
#    'Xmax': -114.29513225,
#    'Ymin': 34.516448000000004,
#    'Ymax': 34.518448,
#    'ExInfo': ''},
#   'extent': {'xmin': -114.29713225,
#    'ymin': 34.516448000000004,
#    'xmax': -114.29513225,
#    'ymax': 34.518448}},
#  {'address': 'Phoenix Ave, Kingman, Arizona, 86401',
#   'location': {'x': -114.01828930507865, 'y': 35.197227},
#   'score': 97.35,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 97.35,
#    'Match_addr': 'Phoenix Ave, Kingman, Arizona, 86401',
#    'LongLabel': 'Phoenix Ave, Kingman, AZ, 86401, USA',
#    'ShortLabel': 'Phoenix Ave',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'Phoenix Ave, Kingman, Arizona, 86401',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': '',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Ave',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'Phoenix Ave',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Kingman',
#    'MetroArea': '',
#    'Subregion': 'Mohave County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '86401',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -114.01828930507865,
#    'Y': 35.197227,
#    'DisplayX': -114.01828930507865,
#    'DisplayY': 35.197227,
#    'Xmin': -114.01928930507866,
#    'Xmax': -114.01728930507865,
#    'Ymin': 35.196227,
#    'Ymax': 35.198226999999996,
#    'ExInfo': ''},
#   'extent': {'xmin': -114.01928930507866,
#    'ymin': 35.196227,
#    'xmax': -114.01728930507865,
#    'ymax': 35.198226999999996}},
#  {'address': 'W Phoenix Ave, Flagstaff, Arizona, 86001',
#   'location': {'x': -111.65265390207907, 'y': 35.19729358236391},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'W Phoenix Ave, Flagstaff, Arizona, 86001',
#    'LongLabel': 'W Phoenix Ave, Flagstaff, AZ, 86001, USA',
#    'ShortLabel': 'W Phoenix Ave',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'W Phoenix Ave, Flagstaff, Arizona, 86001',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'W',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Ave',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'W Phoenix Ave',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'Laplaza Vieja',
#    'District': '',
#    'City': 'Flagstaff',
#    'MetroArea': '',
#    'Subregion': 'Coconino County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '86001',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -111.65265390207907,
#    'Y': 35.19729358236391,
#    'DisplayX': -111.65265390207907,
#    'DisplayY': 35.19729358236391,
#    'Xmin': -111.65365390207907,
#    'Xmax': -111.65165390207906,
#    'Ymin': 35.196293582363914,
#    'Ymax': 35.19829358236391,
#    'ExInfo': ''},
#   'extent': {'xmin': -111.65365390207907,
#    'ymin': 35.196293582363914,
#    'xmax': -111.65165390207906,
#    'ymax': 35.19829358236391}},
#  {'address': 'E Phoenix Ave, Flagstaff, Arizona, 86001',
#   'location': {'x': -111.64795081343148, 'y': 35.19610403918605},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'E Phoenix Ave, Flagstaff, Arizona, 86001',
#    'LongLabel': 'E Phoenix Ave, Flagstaff, AZ, 86001, USA',
#    'ShortLabel': 'E Phoenix Ave',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'E Phoenix Ave, Flagstaff, Arizona, 86001',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'E',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Ave',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'E Phoenix Ave',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'South Side',
#    'District': '',
#    'City': 'Flagstaff',
#    'MetroArea': '',
#    'Subregion': 'Coconino County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '86001',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -111.64795081343148,
#    'Y': 35.19610403918605,
#    'DisplayX': -111.64795081343148,
#    'DisplayY': 35.19610403918605,
#    'Xmin': -111.64895081343148,
#    'Xmax': -111.64695081343147,
#    'Ymin': 35.19510403918605,
#    'Ymax': 35.197104039186044,
#    'ExInfo': ''},
#   'extent': {'xmin': -111.64895081343148,
#    'ymin': 35.19510403918605,
#    'xmax': -111.64695081343147,
#    'ymax': 35.197104039186044}},
#  {'address': 'N Phoenix Ave, Mount Lemmon, Arizona, 85619',
#   'location': {'x': -110.76071011433298, 'y': 32.44233353312554},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'N Phoenix Ave, Mount Lemmon, Arizona, 85619',
#    'LongLabel': 'N Phoenix Ave, Mount Lemmon, AZ, 85619, USA',
#    'ShortLabel': 'N Phoenix Ave',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'N Phoenix Ave, Mount Lemmon, Arizona, 85619',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'N',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Ave',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'N Phoenix Ave',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': 'Summerhaven',
#    'District': '',
#    'City': 'Mount Lemmon',
#    'MetroArea': '',
#    'Subregion': 'Pima County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '85619',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -110.76071011433298,
#    'Y': 32.44233353312554,
#    'DisplayX': -110.76071011433298,
#    'DisplayY': 32.44233353312554,
#    'Xmin': -110.76171011433298,
#    'Xmax': -110.75971011433298,
#    'Ymin': 32.441333533125544,
#    'Ymax': 32.44333353312554,
#    'ExInfo': ''},
#   'extent': {'xmin': -110.76171011433298,
#    'ymin': 32.441333533125544,
#    'xmax': -110.75971011433298,
#    'ymax': 32.44333353312554}},
#  {'address': 'E Phoenix St, Tucson, Arizona, 85707',
#   'location': {'x': -110.8780379989832, 'y': 32.1717852250947},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'E Phoenix St, Tucson, Arizona, 85707',
#    'LongLabel': 'E Phoenix St, Tucson, AZ, 85707, USA',
#    'ShortLabel': 'E Phoenix St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'E Phoenix St, Tucson, Arizona, 85707',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'E',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'E Phoenix St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Tucson',
#    'MetroArea': '',
#    'Subregion': 'Pima County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '85707',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -110.8780379989832,
#    'Y': 32.1717852250947,
#    'DisplayX': -110.8780379989832,
#    'DisplayY': 32.1717852250947,
#    'Xmin': -110.87903799898321,
#    'Xmax': -110.8770379989832,
#    'Ymin': 32.170785225094704,
#    'Ymax': 32.1727852250947,
#    'ExInfo': ''},
#   'extent': {'xmin': -110.87903799898321,
#    'ymin': 32.170785225094704,
#    'xmax': -110.8770379989832,
#    'ymax': 32.1727852250947}},
#  {'address': 'E Phoenix St, Dewey, Arizona, 86327',
#   'location': {'x': -112.23572214349927, 'y': 34.503325968483566},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'E Phoenix St, Dewey, Arizona, 86327',
#    'LongLabel': 'E Phoenix St, Dewey, AZ, 86327, USA',
#    'ShortLabel': 'E Phoenix St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'E Phoenix St, Dewey, Arizona, 86327',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'E',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'E Phoenix St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Dewey',
#    'MetroArea': '',
#    'Subregion': 'Yavapai County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '86327',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -112.23572214349927,
#    'Y': 34.503325968483566,
#    'DisplayX': -112.23572214349927,
#    'DisplayY': 34.503325968483566,
#    'Xmin': -112.23672214349928,
#    'Xmax': -112.23472214349927,
#    'Ymin': 34.50232596848357,
#    'Ymax': 34.50432596848356,
#    'ExInfo': ''},
#   'extent': {'xmin': -112.23672214349928,
#    'ymin': 34.50232596848357,
#    'xmax': -112.23472214349927,
#    'ymax': 34.50432596848356}},
#  {'address': 'S Phoenix Dr, Yuma, Arizona, 85367',
#   'location': {'x': -114.44261399999999, 'y': 32.66310151968532},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'S Phoenix Dr, Yuma, Arizona, 85367',
#    'LongLabel': 'S Phoenix Dr, Yuma, AZ, 85367, USA',
#    'ShortLabel': 'S Phoenix Dr',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'S Phoenix Dr, Yuma, Arizona, 85367',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'S',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Dr',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'S Phoenix Dr',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Yuma',
#    'MetroArea': '',
#    'Subregion': 'Yuma County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '85367',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -114.44261399999999,
#    'Y': 32.66310151968532,
#    'DisplayX': -114.44261399999999,
#    'DisplayY': 32.66310151968532,
#    'Xmin': -114.443614,
#    'Xmax': -114.44161399999999,
#    'Ymin': 32.66210151968532,
#    'Ymax': 32.66410151968532,
#    'ExInfo': ''},
#   'extent': {'xmin': -114.443614,
#    'ymin': 32.66210151968532,
#    'xmax': -114.44161399999999,
#    'ymax': 32.66410151968532}},
#  {'address': 'W Phoenix Ave, Yuma, Arizona, 85364',
#   'location': {'x': -114.66251774999999, 'y': 32.723136000000004},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'W Phoenix Ave, Yuma, Arizona, 85364',
#    'LongLabel': 'W Phoenix Ave, Yuma, AZ, 85364, USA',
#    'ShortLabel': 'W Phoenix Ave',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'W Phoenix Ave, Yuma, Arizona, 85364',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'W',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Ave',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'W Phoenix Ave',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Yuma',
#    'MetroArea': '',
#    'Subregion': 'Yuma County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '85364',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -114.66251774999999,
#    'Y': 32.723136000000004,
#    'DisplayX': -114.66251774999999,
#    'DisplayY': 32.723136000000004,
#    'Xmin': -114.66351775,
#    'Xmax': -114.66151774999999,
#    'Ymin': 32.722136000000006,
#    'Ymax': 32.724136,
#    'ExInfo': ''},
#   'extent': {'xmin': -114.66351775,
#    'ymin': 32.722136000000006,
#    'xmax': -114.66151774999999,
#    'ymax': 32.724136}},
#  {'address': 'N Phoenix St, Florence, Arizona, 85132',
#   'location': {'x': -111.380202, 'y': 33.03462614643472},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'N Phoenix St, Florence, Arizona, 85132',
#    'LongLabel': 'N Phoenix St, Florence, AZ, 85132, USA',
#    'ShortLabel': 'N Phoenix St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'N Phoenix St, Florence, Arizona, 85132',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'N',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'N Phoenix St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Florence',
#    'MetroArea': '',
#    'Subregion': 'Pinal County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '85132',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -111.380202,
#    'Y': 33.03462614643472,
#    'DisplayX': -111.380202,
#    'DisplayY': 33.03462614643472,
#    'Xmin': -111.381202,
#    'Xmax': -111.37920199999999,
#    'Ymin': 33.03362614643472,
#    'Ymax': 33.035626146434716,
#    'ExInfo': ''},
#   'extent': {'xmin': -111.381202,
#    'ymin': 33.03362614643472,
#    'xmax': -111.37920199999999,
#    'ymax': 33.035626146434716}},
#  {'address': 'W Phoenix Ave, Eloy, Arizona, 85131',
#   'location': {'x': -111.56340879154865, 'y': 32.75841479992769},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'W Phoenix Ave, Eloy, Arizona, 85131',
#    'LongLabel': 'W Phoenix Ave, Eloy, AZ, 85131, USA',
#    'ShortLabel': 'W Phoenix Ave',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'W Phoenix Ave, Eloy, Arizona, 85131',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'W',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Ave',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'W Phoenix Ave',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Eloy',
#    'MetroArea': '',
#    'Subregion': 'Pinal County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '85131',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -111.56340879154865,
#    'Y': 32.75841479992769,
#    'DisplayX': -111.56340879154865,
#    'DisplayY': 32.75841479992769,
#    'Xmin': -111.56440879154866,
#    'Xmax': -111.56240879154865,
#    'Ymin': 32.757414799927695,
#    'Ymax': 32.75941479992769,
#    'ExInfo': ''},
#   'extent': {'xmin': -111.56440879154866,
#    'ymin': 32.757414799927695,
#    'xmax': -111.56240879154865,
#    'ymax': 32.75941479992769}},
#  {'address': 'E Phoenix Ave, Eloy, Arizona, 85131',
#   'location': {'x': -111.55234738266806, 'y': 32.755625325209},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'E Phoenix Ave, Eloy, Arizona, 85131',
#    'LongLabel': 'E Phoenix Ave, Eloy, AZ, 85131, USA',
#    'ShortLabel': 'E Phoenix Ave',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'E Phoenix Ave, Eloy, Arizona, 85131',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'E',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'Ave',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'E Phoenix Ave',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Eloy',
#    'MetroArea': '',
#    'Subregion': 'Pinal County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '85131',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -111.55234738266806,
#    'Y': 32.755625325209,
#    'DisplayX': -111.55234738266806,
#    'DisplayY': 32.755625325209,
#    'Xmin': -111.55334738266806,
#    'Xmax': -111.55134738266806,
#    'Ymin': 32.754625325209005,
#    'Ymax': 32.756625325209,
#    'ExInfo': ''},
#   'extent': {'xmin': -111.55334738266806,
#    'ymin': 32.754625325209005,
#    'xmax': -111.55134738266806,
#    'ymax': 32.756625325209}},
#  {'address': 'E Phoenix St, Payson, Arizona, 85541',
#   'location': {'x': -111.3108272313043, 'y': 34.22556781037371},
#   'score': 96.42,
#   'attributes': {'Loc_name': 'World',
#    'Status': 'T',
#    'Score': 96.42,
#    'Match_addr': 'E Phoenix St, Payson, Arizona, 85541',
#    'LongLabel': 'E Phoenix St, Payson, AZ, 85541, USA',
#    'ShortLabel': 'E Phoenix St',
#    'Addr_type': 'StreetName',
#    'Type': '',
#    'PlaceName': '',
#    'Place_addr': 'E Phoenix St, Payson, Arizona, 85541',
#    'Phone': '',
#    'URL': '',
#    'Rank': 20,
#    'AddBldg': '',
#    'AddNum': '',
#    'AddNumFrom': '',
#    'AddNumTo': '',
#    'AddRange': '',
#    'Side': '',
#    'StPreDir': 'E',
#    'StPreType': '',
#    'StName': 'Phoenix',
#    'StType': 'St',
#    'StDir': '',
#    'BldgType': '',
#    'BldgName': '',
#    'LevelType': '',
#    'LevelName': '',
#    'UnitType': '',
#    'UnitName': '',
#    'SubAddr': '',
#    'StAddr': 'E Phoenix St',
#    'Block': '',
#    'Sector': '',
#    'Nbrhd': '',
#    'District': '',
#    'City': 'Payson',
#    'MetroArea': '',
#    'Subregion': 'Gila County',
#    'Region': 'Arizona',
#    'RegionAbbr': 'AZ',
#    'Territory': '',
#    'Zone': '',
#    'Postal': '85541',
#    'PostalExt': '',
#    'Country': 'USA',
#    'LangCode': 'ENG',
#    'Distance': 0,
#    'X': -111.3108272313043,
#    'Y': 34.22556781037371,
#    'DisplayX': -111.3108272313043,
#    'DisplayY': 34.22556781037371,
#    'Xmin': -111.3118272313043,
#    'Xmax': -111.3098272313043,
#    'Ymin': 34.22456781037371,
#    'Ymax': 34.22656781037371,
#    'ExInfo': ''},
#   'extent': {'xmin': -111.3118272313043,
#    'ymin': 34.22456781037371,
#    'xmax': -111.3098272313043,
#    'ymax': 34.22656781037371}}]

# %%
len(results)
# Out:
# 20

# %%
results[0]
# Out:
# {'address': 'Phoenix, Arizona',
#  'location': {'x': -112.07579999999996, 'y': 33.44825000000003},
#  'score': 100,
#  'attributes': {'Loc_name': 'World',
#   'Status': 'T',
#   'Score': 100,
#   'Match_addr': 'Phoenix, Arizona',
#   'LongLabel': 'Phoenix, AZ, USA',
#   'ShortLabel': 'Phoenix',
#   'Addr_type': 'Locality',
#   'Type': 'City',
#   'PlaceName': 'Phoenix',
#   'Place_addr': 'Phoenix, Arizona',
#   'Phone': '',
#   'URL': '',
#   'Rank': 2,
#   'AddBldg': '',
#   'AddNum': '',
#   'AddNumFrom': '',
#   'AddNumTo': '',
#   'AddRange': '',
#   'Side': '',
#   'StPreDir': '',
#   'StPreType': '',
#   'StName': '',
#   'StType': '',
#   'StDir': '',
#   'BldgType': '',
#   'BldgName': '',
#   'LevelType': '',
#   'LevelName': '',
#   'UnitType': '',
#   'UnitName': '',
#   'SubAddr': '',
#   'StAddr': '',
#   'Block': '',
#   'Sector': '',
#   'Nbrhd': '',
#   'District': '',
#   'City': 'Phoenix',
#   'MetroArea': 'Phoenix Metro Area',
#   'Subregion': 'Maricopa County',
#   'Region': 'Arizona',
#   'RegionAbbr': 'AZ',
#   'Territory': '',
#   'Zone': '',
#   'Postal': '',
#   'PostalExt': '',
#   'Country': 'USA',
#   'LangCode': 'ENG',
#   'Distance': 0,
#   'X': -112.07579999999996,
#   'Y': 33.44825000000003,
#   'DisplayX': -112.07579999999996,
#   'DisplayY': 33.44825000000003,
#   'Xmin': -112.33279999999996,
#   'Xmax': -111.81879999999995,
#   'Ymin': 33.19125000000003,
#   'Ymax': 33.70525000000003,
#   'ExInfo': ''},
#  'extent': {'xmin': -112.33279999999996,
#   'ymin': 33.19125000000003,
#   'xmax': -111.81879999999995,
#   'ymax': 33.70525000000003}}

# %%
map1 = gis.map('Phoenix, AZ')
map1
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-4c7990af-46f2-4982-9398-1cc931f5b70c"><img src=""></img></div>

# %%
symbol = {
    "type" : "simple-marker",
    "style" : "diamond",
    "color" : [230, 76, 0, 1]
}
map1.draw(results[0]['location'], symbol=symbol)

# %% [markdown]
# ### Geocode single line addresses

# %%
r2 = geocoding.geocode('Pointe Hilton Squaw Peak Resort')
len(r2)
# Out:
# 1

# %%
[str(r['score']) +"  :  "+ r['attributes']['Match_addr'] for r in r2]
# Out:
# ['97  :  Hilton-Pointe Squaw Peak Resort']

# %% [markdown]
# ### Geocode multi field address

# %%
multi_field_address = { 
    "Address" : "111 Harbor Dr",
    "City" : "San Diego",
    "Region" : "CA",
    "Subregion":"San Diego",
    "Postal" : 92103,
    "Country":"USA"
    }
r_multi_fields = geocoding.geocode(multi_field_address)
len(r_multi_fields)
# Out:
# 16

# %% [markdown]
# ### Searching within an exent
# Find restaurants within walking distance of this training center (Hard Rock Hotel, Palm Springs)

# %%
# first create an extent.
conv_center = geocoding.geocode('walter e washington convention center')[0]
map3 = gis.map('Washington, DC', zoomlevel=13)
map3
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=13.0)
# <div class="map-static-img-preview-a61feac4-abe2-474e-8890-9c72ec3ad781"><img src=""></img></div>

# %%
restaurants = geocoding.geocode('restaurants',search_extent=conv_center['extent'], 
                                max_locations=15)
len(restaurants)
# Out:
# 15

# %%
map3.clear_graphics()

# %%
for shop in restaurants:
    popup = { 
    "title" : shop['attributes']['PlaceName'], 
    "content" : shop['attributes']['Place_addr']
    }
    map3.draw(shop['location'],popup, symbol=symbol)

# %% [markdown]
# ## Batch geocoding

# %%
addresses = ["380 New York St, Redlands, CA", 
             "1 World Way, Los Angeles, CA",
             "1200 Getty Center Drive, Los Angeles, CA", 
             "5905 Wilshire Boulevard, Los Angeles, CA",
             "100 Universal City Plaza, Universal City, CA 91608",
             "4800 Oak Grove Dr, Pasadena, CA 91109"]

# %%
results = geocoding.batch_geocode(addresses)

# %%
len(results)
# Out:
# 6

# %%
map5 = gis.map('Los Angeles, CA')
map5
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-4132ebcc-487f-48d5-bcee-c18638e983d2"><img src=""></img></div>

# %%
for address in results:
    map5.draw(address['location'], symbol=symbol)

# %% [markdown]
# ## Reverse geocoding

# %%
reverse_geocode_results = geocoding.reverse_geocode([2.2945, 48.8583])
reverse_geocode_results
# Out:
# {'address': {'Match_addr': 'Salle Gustave Eiffel',
#   'LongLabel': 'Salle Gustave Eiffel, Avenue Gustave Eiffel, 75007, 7e Arrondissement, Paris, Île-de-France, FRA',
#   'ShortLabel': 'Salle Gustave Eiffel',
#   'Addr_type': 'POI',
#   'Type': 'Convention Center',
#   'PlaceName': 'Salle Gustave Eiffel',
#   'AddNum': '',
#   'Address': 'Avenue Gustave Eiffel',
#   'Block': '',
#   'Sector': '',
#   'Neighborhood': 'Gros Caillou',
#   'District': '7e Arrondissement',
#   'City': 'Paris',
#   'MetroArea': '',
#   'Subregion': 'Paris',
#   'Region': 'Île-de-France',
#   'Territory': '',
#   'Postal': '75007',
#   'PostalExt': '',
#   'CountryCode': 'FRA'},
#  'location': {'x': 2.2951599583073303,
#   'y': 48.85784000836726,
#   'spatialReference': {'wkid': 4326, 'latestWkid': 4326}}}

# %%
map6 = gis.map('Washington, DC', 16)
map6
# Out:
# MapView(layout=Layout(height='400px', width='100%'), zoom=16.0)
# <div class="map-static-img-preview-dfeb1d9d-509f-492d-a0fa-d4ef55f3e292"><img src=""></img></div>
# Bullfinch Gatehouses (Formerly U.S. Capitoal Gatehouse), 15th St NW, Washington, District of Columbia, 20004
# 947-983 Constitution Ave NW, Washington, District of Columbia, 20004
# World War Ii Memorial

# %%
def find_addr(map6, g):
    try:
        map6.draw(g, symbol=symbol)
        geocoded = geocoding.reverse_geocode(g)
        print(geocoded['address']['Match_addr'])
    except:
        print("Couldn't match address. Try another place...")

# %%
map6.on_click(find_addr)
